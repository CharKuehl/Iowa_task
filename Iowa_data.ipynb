# %% [markdown]
# <a href="https://colab.research.google.com/github/CharKuehl/Iowa_task/blob/main/Iowa_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Iowa Gambling Task (IGT)
#
# The IGT is a psychological experiment to evaluate human decision making in order to draw conclusions about psychological diseases. Conditions such as schizophrenia and obsessive compulsive disorder are currently investigated in combining IGT with functional imaging technologies.
#
# ![Iowa_gambling_im.jpeg](data:image/jpeg;base64,...)
# [http://doi.org/10.5334/jopd.ak](https://openpsychologydata.metajnl.com/articles/10.5334/jopd.ak/)

# %% [markdown]
# 0) import everything

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch

# %% [markdown]
# 1) Improrting all csv files

# %%
import csv
with open('')
